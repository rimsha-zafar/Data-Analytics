# %% [markdown]
# ### Import all the libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the sustainability dataset csv file

# %%
data = pd.read_csv('WorldSustainabilityDataset.csv')

# %%
data
# Out:
#      Country Name Country Code  Year  \
# 0           Aruba          ABW  2000
# 1           Aruba          ABW  2001
# 2           Aruba          ABW  2002
# 3           Aruba          ABW  2003
# 4           Aruba          ABW  2004
# ...           ...          ...   ...
# 3282     Zimbabwe          ZWE  2014
# 3283     Zimbabwe          ZWE  2015
# 3284     Zimbabwe          ZWE  2016
# 3285     Zimbabwe          ZWE  2017
# 3286     Zimbabwe          ZWE  2018
#
#       Access to electricity (% of population) - EG.ELC.ACCS.ZS  \
# 0                                             91.660398
# 1                                            100.000000
# 2                                            100.000000
# 3                                            100.000000
# 4                                            100.000000
# ...                                                 ...
# 3282                                          32.300000
# 3283                                          33.700000
# 3284                                          39.676228
# 3285                                          40.144283
# 3286                                          40.616360
#
#       Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3282                                           0.763955
# 3283                                          10.749009
# 3284                                          -0.716048
# 3285                                          28.172572
# 3286                                          61.556580
#
#       Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS  \
# 0                                             15.392211
# 1                                             11.491930
# 2                                              3.893620
# 3                                              6.713863
# 4                                              9.801576
# ...                                                 ...
# 3282                                         -14.094023
# 3283                                         -18.882831
# 3284                                         -11.199213
# 3285                                         -12.700238
# 3286                                                NaN
#
#       Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS  \
# 0                                              2.389134
# 1                                              2.509046
# 2                                              2.721385
# 3                                              2.733676
# 4                                              2.678363
# ...                                                 ...
# 3282                                           2.310859
# 3283                                           2.381654
# 3284                                           2.101249
# 3285                                           2.102515
# 3286                                           2.003068
#
#       Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS  \
# 0                                              0.000190
# 1                                              0.000214
# 2                                              0.000223
# 3                                              0.000243
# 4                                              0.000256
# ...                                                 ...
# 3282                                           1.573499
# 3283                                           0.844003
# 3284                                           0.823740
# 3285                                           1.300127
# 3286                                           2.085152
#
#       Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS  \
# 0                                              0.000190
# 1                                              0.000214
# 2                                              0.000223
# 3                                              0.000243
# 4                                              0.000256
# ...                                                 ...
# 3282                                           0.000000
# 3283                                           0.000000
# 3284                                           0.000000
# 3285                                           0.000000
# 3286                                           0.000000
#
#       Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3282                                           1.426705
# 3283                                           1.492774
# 3284                                           1.496494
# 3285                                           1.422511
# 3286                                           1.422511
#
#       ...  Gini index (World Bank estimate) - SI.POV.GINI  \
# 0     ...                                             NaN
# 1     ...                                             NaN
# 2     ...                                             NaN
# 3     ...                                             NaN
# 4     ...                                             NaN
# ...   ...                                             ...
# 3282  ...                                             NaN
# 3283  ...                                             NaN
# 3284  ...                                             NaN
# 3285  ...                                            44.3
# 3286  ...                                             NaN
#
#       Income Classification (World Bank Definition)  \
# 0                                       High income
# 1                                       High income
# 2                                       High income
# 3                                       High income
# 4                                       High income
# ...                                             ...
# 3282                                     Low income
# 3283                                     Low income
# 3284                                     Low income
# 3285                                     Low income
# 3286                                     Low income
#
#       Individuals using the Internet (% of population) - IT.NET.USER.ZS  \
# 0                                                   NaN
# 1                                             17.100000
# 2                                             18.800000
# 3                                             20.800000
# 4                                             23.000000
# ...                                                 ...
# 3282                                          16.364740
# 3283                                          22.742818
# 3284                                          23.119989
# 3285                                          24.400000
# 3286                                          25.000000
#
#       Life expectancy at birth, total (years) - SP.DYN.LE00.IN  \
# 0                                                   NaN
# 1                                                73.853
# 2                                                73.937
# 3                                                74.038
# 4                                                74.156
# ...                                                 ...
# 3282                                             58.410
# 3283                                             59.534
# 3284                                             60.294
# 3285                                             60.812
# 3286                                             61.195
#
#       Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)  \
# 0                                 NaN                                   NaN
# 1                             92892.0                                   NaN
# 2                             94992.0                                   NaN
# 3                             97016.0                                   NaN
# 4                             98744.0                                   NaN
# ...                               ...                                   ...
# 3282                       13586710.0                   Electoral Autocracy
# 3283                       13814642.0                   Electoral Autocracy
# 3284                       14030338.0                   Electoral Autocracy
# 3285                       14236599.0                   Electoral Autocracy
# 3286                       14438812.0                   Electoral Autocracy
#
#       Rural population (% of total population) - SP.RUR.TOTL.ZS  \
# 0                                                53.283
# 1                                                53.661
# 2                                                54.028
# 3                                                54.394
# 4                                                54.760
# ...                                                 ...
# 3282                                             67.496
# 3283                                             67.615
# 3284                                             67.704
# 3285                                             67.763
# 3286                                             67.791
#
#       Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS  \
# 0                                                   NaN
# 1                                              0.000712
# 2                                              0.000657
# 3                                              0.000700
# 4                                              0.000685
# ...                                                 ...
# 3282                                           5.531514
# 3283                                           4.561981
# 3284                                           4.473632
# 3285                                           4.844665
# 3286                                           4.363782
#
#       Urban population (% of total population) - SP.URB.TOTL.IN.ZS  \
# 0                                                   NaN
# 1                                                46.339
# 2                                                45.972
# 3                                                45.606
# 4                                                45.240
# ...                                                 ...
# 3282                                             32.504
# 3283                                             32.385
# 3284                                             32.296
# 3285                                             32.237
# 3286                                             32.209
#
#       World Regions (UN SDG Definition)
# 0           Latin America and Caribbean
# 1           Latin America and Caribbean
# 2           Latin America and Caribbean
# 3           Latin America and Caribbean
# 4           Latin America and Caribbean
# ...                                 ...
# 3282                 Sub-Saharan Africa
# 3283                 Sub-Saharan Africa
# 3284                 Sub-Saharan Africa
# 3285                 Sub-Saharan Africa
# 3286                 Sub-Saharan Africa
#
# [3287 rows x 54 columns]

# %% [markdown]
# ### Renaming columns in a dataframe

# %%
data = data.rename(columns={'Access to electricity (% of population) - EG.ELC.ACCS.ZS': '%population_with_electricity', 'Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG': '%GNIgrowth', 'Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS':'%netemissionsavings', 'Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS':'%CO2savings', 'Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS':'%NRD', 'Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS':'%PPdamage', 'Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS':'%FD','Gini index (World Bank estimate) - SI.POV.GINI':'GINIindex', 'Income Classification (World Bank Definition)': 'Incomeclass', 'Individuals using the Internet (% of population) - IT.NET.USER.ZS':'%internetuse', 'Life expectancy at birth, total (years) - SP.DYN.LE00.IN':'LEB','Population, total - SP.POP.TOTL':'population', 'Rural population (% of total population) - SP.RUR.TOTL.ZS':'ruralpopulation', 'Regime Type (RoW Measure Definition)':'regime', 'Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS':'NRrent','Urban population (% of total population) - SP.URB.TOTL.IN.ZS':'urbanpopulation','World Regions (UN SDG Definition)':'worldregions'})

# %%
data
# Out:
#      Country Name Country Code  Year  %population_with_electricity  \
# 0           Aruba          ABW  2000                     91.660398
# 1           Aruba          ABW  2001                    100.000000
# 2           Aruba          ABW  2002                    100.000000
# 3           Aruba          ABW  2003                    100.000000
# 4           Aruba          ABW  2004                    100.000000
# ...           ...          ...   ...                           ...
# 3282     Zimbabwe          ZWE  2014                     32.300000
# 3283     Zimbabwe          ZWE  2015                     33.700000
# 3284     Zimbabwe          ZWE  2016                     39.676228
# 3285     Zimbabwe          ZWE  2017                     40.144283
# 3286     Zimbabwe          ZWE  2018                     40.616360
#
#       %GNIgrowth  %netemissionsavings  %CO2savings      %NRD       %FD  \
# 0            NaN            15.392211     2.389134  0.000190  0.000190
# 1            NaN            11.491930     2.509046  0.000214  0.000214
# 2            NaN             3.893620     2.721385  0.000223  0.000223
# 3            NaN             6.713863     2.733676  0.000243  0.000243
# 4            NaN             9.801576     2.678363  0.000256  0.000256
# ...          ...                  ...          ...       ...       ...
# 3282    0.763955           -14.094023     2.310859  1.573499  0.000000
# 3283   10.749009           -18.882831     2.381654  0.844003  0.000000
# 3284   -0.716048           -11.199213     2.101249  0.823740  0.000000
# 3285   28.172572           -12.700238     2.102515  1.300127  0.000000
# 3286   61.556580                  NaN     2.003068  2.085152  0.000000
#
#       %PPdamage  ...  GINIindex  Incomeclass  %internetuse     LEB  \
# 0           NaN  ...        NaN  High income           NaN     NaN
# 1           NaN  ...        NaN  High income     17.100000  73.853
# 2           NaN  ...        NaN  High income     18.800000  73.937
# 3           NaN  ...        NaN  High income     20.800000  74.038
# 4           NaN  ...        NaN  High income     23.000000  74.156
# ...         ...  ...        ...          ...           ...     ...
# 3282   1.426705  ...        NaN   Low income     16.364740  58.410
# 3283   1.492774  ...        NaN   Low income     22.742818  59.534
# 3284   1.496494  ...        NaN   Low income     23.119989  60.294
# 3285   1.422511  ...       44.3   Low income     24.400000  60.812
# 3286   1.422511  ...        NaN   Low income     25.000000  61.195
#
#       population               regime  ruralpopulation    NRrent  \
# 0            NaN                  NaN           53.283       NaN
# 1        92892.0                  NaN           53.661  0.000712
# 2        94992.0                  NaN           54.028  0.000657
# 3        97016.0                  NaN           54.394  0.000700
# 4        98744.0                  NaN           54.760  0.000685
# ...          ...                  ...              ...       ...
# 3282  13586710.0  Electoral Autocracy           67.496  5.531514
# 3283  13814642.0  Electoral Autocracy           67.615  4.561981
# 3284  14030338.0  Electoral Autocracy           67.704  4.473632
# 3285  14236599.0  Electoral Autocracy           67.763  4.844665
# 3286  14438812.0  Electoral Autocracy           67.791  4.363782
#
#       urbanpopulation                 worldregions
# 0                 NaN  Latin America and Caribbean
# 1              46.339  Latin America and Caribbean
# 2              45.972  Latin America and Caribbean
# 3              45.606  Latin America and Caribbean
# 4              45.240  Latin America and Caribbean
# ...               ...                          ...
# 3282           32.504           Sub-Saharan Africa
# 3283           32.385           Sub-Saharan Africa
# 3284           32.296           Sub-Saharan Africa
# 3285           32.237           Sub-Saharan Africa
# 3286           32.209           Sub-Saharan Africa
#
# [3287 rows x 54 columns]

# %%
data.describe()
# Out:
#               Year  %population_with_electricity   %GNIgrowth  \
# count  3287.000000                   3193.000000  2566.000000
# mean   2009.000000                     79.300662     2.499857
# std       5.478059                     30.398748    18.752649
# min    2000.000000                      1.270180  -645.655290
# 25%    2004.000000                     62.900000    -0.246761
# 50%    2009.000000                     98.653969     2.545392
# 75%    2014.000000                    100.000000     5.545831
# max    2018.000000                    100.000000   229.493078
#
#        %netemissionsavings  %CO2savings         %NRD          %FD  \
# count          2628.000000  3220.000000  3094.000000  3111.000000
# mean              8.870028     1.742674     3.812051     0.692833
# std              12.277347     1.957442     6.958003     2.657800
# min             -97.524776     0.090292     0.000000     0.000000
# 25%               3.339159     0.741310     0.078542     0.000000
# 50%               8.752619     1.145867     0.878741     0.000000
# 75%              15.290790     2.056927     4.656705     0.097040
# max              45.354086    27.101473    71.290764    40.772569
#
#          %PPdamage  \
# count  3099.000000
# mean      0.880541
# std       1.084312
# min       0.009500
# 25%       0.149597
# 50%       0.388686
# 75%       1.286091
# max       6.542877
#
#        Automated teller machines (ATMs) (per 100,000 adults) - FB.ATM.TOTL.P5  \
# count                                        2285.000000
# mean                                           45.391741
# std                                            45.915444
# min                                             0.000000
# 25%                                             9.558670
# 50%                                            34.951665
# 75%                                            62.252217
# max                                           324.172288
#
#        Broad money (% of GDP) - FM.LBL.BMNY.GD.ZS  ...  \
# count                                 2777.000000  ...
# mean                                    57.034297  ...
# std                                     43.806176  ...
# min                                      2.857408  ...
# 25%                                     27.222821  ...
# 50%                                     47.054379  ...
# 75%                                     72.465711  ...
# max                                    396.185604  ...
#
#        Unemployment rate, male (%) - SL_TLF_UEM - 8.5.2  \
# count                                       1807.000000
# mean                                           7.987327
# std                                            5.781539
# min                                            0.100000
# 25%                                            4.100000
# 50%                                            6.400000
# 75%                                           10.000000
# max                                           37.000000
#
#        Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2  \
# count                                        1806.000000
# mean                                            9.810687
# std                                             7.159265
# min                                             0.200000
# 25%                                             4.725000
# 50%                                             7.500000
# 75%                                            12.800000
# max                                            42.800000
#
#        Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes  \
# count                                        3285.000000
# mean                                          174.646907
# std                                           757.653194
# min                                             0.048000
# 25%                                             2.426000
# 50%                                            12.621000
# 75%                                            72.012000
# max                                          9956.569000
#
#          GINIindex  %internetuse          LEB    population  ruralpopulation  \
# count  1303.000000   2986.000000  3096.000000  3.106000e+03      3278.000000
# mean     37.512203     33.117667    70.160098  3.891506e+07        42.890186
# std       8.595502     29.386654     9.205632  1.413757e+08        22.705962
# min      23.700000      0.000000    40.369000  6.967100e+04         0.000000
# 25%      30.900000      6.000000    65.109000  2.406866e+06        24.816500
# 50%      35.600000     25.000000    72.564634  8.368371e+06        42.648000
# 75%      42.800000     58.000000    76.572750  2.605396e+07        60.732750
# max      64.800000     99.652849    84.934146  1.392730e+09        91.754000
#
#             NRrent  urbanpopulation
# count  3053.000000      3106.000000
# mean      7.015880        57.264100
# std      10.730922        22.687638
# min       0.000000         8.461000
# 25%       0.385851        39.546750
# 50%       2.122046        57.450000
# 75%       8.878282        75.372500
# max      81.949962       100.000000
#
# [8 rows x 48 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 54 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Country Name                                                                                  3287 non-null   object
#  1   Country Code                                                                                  3287 non-null   object
#  2   Year                                                                                          3287 non-null   int64
#  3   %population_with_electricity                                                                  3193 non-null   float64
#  4   %GNIgrowth                                                                                    2566 non-null   float64
#  5   %netemissionsavings                                                                           2628 non-null   float64
#  6   %CO2savings                                                                                   3220 non-null   float64
#  7   %NRD                                                                                          3094 non-null   float64
#  8   %FD                                                                                           3111 non-null   float64
#  9   %PPdamage                                                                                     3099 non-null   float64
#  10  Automated teller machines (ATMs) (per 100,000 adults) - FB.ATM.TOTL.P5                        2285 non-null   float64
#  11  Broad money (% of GDP) - FM.LBL.BMNY.GD.ZS                                                    2777 non-null   float64
#  12  Children out of school (% of primary school age) - SE.PRM.UNER.ZS                             2225 non-null   float64
#  13  Compulsory education, duration (years) - SE.COM.DURS                                          2979 non-null   float64
#  14  Cost of business start-up procedures, female (% of GNI per capita) - IC.REG.COST.PC.FE.ZS     2501 non-null   float64
#  15  Cost of business start-up procedures, male (% of GNI per capita) - IC.REG.COST.PC.MA.ZS       2501 non-null   float64
#  16  Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                     3118 non-null   float64
#  17  Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                     3047 non-null   float64
#  18  GDP (current US$) - NY.GDP.MKTP.CD                                                            3246 non-null   float64
#  19  GDP per capita (current US$) - NY.GDP.PCAP.CD                                                 3246 non-null   float64
#  20  General government final consumption expenditure (% of GDP) - NE.CON.GOVT.ZS                  3031 non-null   float64
#  21  Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                        3047 non-null   float64
#  22  Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                     2774 non-null   float64
#  23  Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                     3118 non-null   float64
#  24  Inflation, consumer prices (annual %) - FP.CPI.TOTL.ZG                                        3083 non-null   float64
#  25  Primary completion rate, total (% of relevant age group) - SE.PRM.CMPT.ZS                     2226 non-null   float64
#  26  Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS                3062 non-null   float64
#  27  Pupil-teacher ratio, primary - SE.PRM.ENRL.TC.ZS                                              2366 non-null   float64
#  28  Renewable electricity output (% of total electricity output) - EG.ELC.RNEW.ZS                 2771 non-null   float64
#  29  Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS           3287 non-null   float64
#  30  School enrollment, preprimary (% gross) - SE.PRE.ENRR                                         2349 non-null   float64
#  31  School enrollment, primary (% gross) - SE.PRM.ENRR                                            2783 non-null   float64
#  32  School enrollment, secondary (% gross) - SE.SEC.ENRR                                          2430 non-null   float64
#  33  Trade (% of GDP) - NE.TRD.GNFS.ZS                                                             3118 non-null   float64
#  34  Women Business and the Law Index Score (scale 1-100) - SG.LAW.INDX                            3211 non-null   float64
#  35  Prevalence of undernourishment (%) - SN_ITK_DEFC - 2.1.1                                      1834 non-null   float64
#  36  Proportion of population below international poverty line (%) - SI_POV_DAY1 - 1.1.1           1304 non-null   float64
#  37  Proportion of population covered by at least a 2G mobile network (%) - IT_MOB_2GNTWK - 9.c.1  2349 non-null   float64
#  38  Proportion of population covered by at least a 3G mobile network (%) - IT_MOB_3GNTWK - 9.c.1  1357 non-null   float64
#  39  Proportion of population using basic drinking water services (%) - SP_ACS_BSRVH2O - 1.4.1     1837 non-null   float64
#  40  Unemployment rate, male (%) - SL_TLF_UEM - 8.5.2                                              1807 non-null   float64
#  41  Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2                                             1806 non-null   float64
#  42  Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes         3285 non-null   float64
#  43  Continent                                                                                     3285 non-null   object
#  44  GINIindex                                                                                     1303 non-null   float64
#  45  Incomeclass                                                                                   3285 non-null   object
#  46  %internetuse                                                                                  2986 non-null   float64
#  47  LEB                                                                                           3096 non-null   float64
#  48  population                                                                                    3106 non-null   float64
#  49  regime                                                                                        3076 non-null   object
#  50  ruralpopulation                                                                               3278 non-null   float64
#  51  NRrent                                                                                        3053 non-null   float64
#  52  urbanpopulation                                                                               3106 non-null   float64
#  53  worldregions                                                                                  3285 non-null   object
# dtypes: float64(47), int64(1), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Check the category names and number of a categorical column using unique()

# %%
data.worldregions.unique()
# Out:
# array(['Latin America and Caribbean', 'Sub-Saharan Africa',
#        'Europe and Northern America', 'Northern Africa and Western Asia',
#        'Oceania', 'Central and Southern Asia',
#        'Eastern and South-Eastern Asia', nan], dtype=object)

# %%
data.Continent.unique()
# Out:
# array(['North America', 'Africa', 'Europe', 'Asia', 'South America',
#        'Oceania', nan], dtype=object)

# %%
data.worldregions.nunique()
# Out:
# 7

# %% [markdown]
# ### Filtering a dataframe with a single and multiple conditions

# %%
data[ (data['%CO2savings'] > 10) ]
# Out:
#             Country Name Country Code  Year  %population_with_electricity  \
# 171           Azerbaijan          AZE  2000                     98.908222
# 172           Azerbaijan          AZE  2001                     98.623421
# 173           Azerbaijan          AZE  2002                    100.000000
# 1198   Equatorial Guinea          GNQ  2001                           NaN
# 1199   Equatorial Guinea          GNQ  2002                           NaN
# 1200   Equatorial Guinea          GNQ  2003                           NaN
# 1201   Equatorial Guinea          GNQ  2004                           NaN
# 1577          Kazakhstan          KAZ  2000                     99.473686
# 1578          Kazakhstan          KAZ  2001                     99.650000
# 1579          Kazakhstan          KAZ  2002                     99.810000
# 1580          Kazakhstan          KAZ  2003                     99.920000
# 2071            Mongolia          MNG  2000                     67.300000
# 2072            Mongolia          MNG  2001                     71.706161
# 2073            Mongolia          MNG  2002                     72.801590
# 2074            Mongolia          MNG  2003                     76.300000
# 2084            Mongolia          MNG  2013                     81.200000
# 2088            Mongolia          MNG  2017                     93.876060
# 2089            Mongolia          MNG  2018                     98.100000
# 2565  Russian Federation          RUS  2000                    100.000000
# 3078             Ukraine          UKR  2000                    100.000000
# 3079             Ukraine          UKR  2001                    100.000000
# 3080             Ukraine          UKR  2002                    100.000000
# 3081             Ukraine          UKR  2003                    100.000000
# 3082             Ukraine          UKR  2004                    100.000000
# 3135          Uzbekistan          UZB  2000                     99.572937
# 3136          Uzbekistan          UZB  2001                     99.624657
# 3137          Uzbekistan          UZB  2002                     99.700000
# 3138          Uzbekistan          UZB  2003                     99.702042
# 3139          Uzbekistan          UZB  2004                     99.725365
# 3140          Uzbekistan          UZB  2005                     99.737022
# 3141          Uzbekistan          UZB  2006                     99.490096
# 3142          Uzbekistan          UZB  2007                     99.739029
# 3143          Uzbekistan          UZB  2008                     99.741684
#
#       %GNIgrowth  %netemissionsavings  %CO2savings       %NRD  %FD  %PPdamage  \
# 171     1.137421           -31.614559    11.096608  27.716228  0.0   0.618628
# 172    18.305685           -19.567133    10.451652  20.732720  0.0   0.540368
# 173    32.064224            -9.026698    10.198892   9.562157  0.0   0.487371
# 1198         NaN                  NaN    14.310159        NaN  0.0   3.113382
# 1199         NaN                  NaN    15.590296        NaN  0.0   2.604163
# 1200         NaN                  NaN    17.469984        NaN  0.0   3.108421
# 1201         NaN                  NaN    10.500161        NaN  0.0   2.896478
# 1577   -6.224749           -21.258744    12.782940  17.479306  0.0   0.696918
# 1578   21.664926           -11.492679    12.147002  12.629144  0.0   0.594688
# 1579    5.788644            -8.387653    11.393885  15.533607  0.0   0.518529
# 1580   13.956759            -6.832350    10.210644  14.075023  0.0   0.476303
# 2071         NaN            -1.393916    12.314631   2.356965  0.0   1.117981
# 2072         NaN            -1.655352    12.081737   1.844769  0.0   1.017996
# 2073         NaN            -1.944064    11.996429   2.438039  0.0   0.948503
# 2074         NaN             8.090429    10.646289   2.020454  0.0   0.837724
# 2084   11.532413             5.798884    11.874613   8.751378  0.0   0.501888
# 2088   -4.596256            -0.973864    10.563178   8.645040  0.0   0.626390
# 2089    4.867136             1.866948    10.268545  10.944186  0.0   0.626390
# 2565   22.796207             3.270014    11.433689   9.256511  0.0   0.324739
# 3078    7.754947            -9.741630    19.650519   1.467658  0.0   0.354199
# 3079   10.449766            -4.328779    16.733725   1.615184  0.0   0.321567
# 3080    7.154552            -0.368508    15.383116   1.261390  0.0   0.320388
# 3081    9.474664            -0.082846    14.941228   1.271035  0.0   0.301230
# 3082   16.946984             8.756910    11.791692   1.084766  0.0   0.294192
# 3135   -7.046875                  NaN    16.701913  12.793952  0.0   0.978134
# 3136   -5.518212                  NaN    21.389198  19.052519  0.0   0.945026
# 3137    5.071618                  NaN    27.101473  17.428238  0.0   0.901909
# 3138    1.601223                  NaN    26.629226  18.662123  0.0   0.856237
# 3139   11.130161                  NaN    23.188402  16.385330  0.0   0.788450
# 3140    4.894925                  NaN    19.069723  15.025776  0.0   0.764046
# 3141   -2.980788                  NaN    17.075874  21.912502  0.0   0.719646
# 3142   20.186788                  NaN    13.290595  18.116357  0.0   0.648938
# 3143   -1.354388                  NaN    10.613799  21.053846  0.0   0.601444
#
#       ...  GINIindex          Incomeclass  %internetuse        LEB  \
# 171   ...        NaN           Low income           NaN        NaN
# 172   ...       36.5           Low income      0.305565  67.054000
# 173   ...       25.3           Low income      4.999714  67.391000
# 1198  ...        NaN           Low income      0.165260  53.581000
# 1199  ...        NaN           Low income      0.321198  53.840000
# 1200  ...        NaN           Low income      0.520524  54.064000
# 1201  ...        NaN  Upper-middle income      0.843930  54.263000
# 1577  ...        NaN  Lower-middle income           NaN        NaN
# 1578  ...       36.0  Lower-middle income      1.006124  65.760000
# 1579  ...       34.8  Lower-middle income      1.674771  65.950000
# 1580  ...       33.7  Lower-middle income      2.000415  65.740000
# 2071  ...        NaN           Low income           NaN        NaN
# 2072  ...        NaN           Low income      1.653238  63.319000
# 2073  ...       32.9           Low income      2.039573  63.777000
# 2074  ...        NaN           Low income           NaN  64.230000
# 2084  ...        NaN  Lower-middle income     17.699984  68.566000
# 2088  ...        NaN  Lower-middle income     23.714265  69.509000
# 2089  ...       32.7  Lower-middle income     47.130002  69.689000
# 2565  ...       37.1  Lower-middle income           NaN        NaN
# 3078  ...        NaN           Low income           NaN        NaN
# 3079  ...        NaN           Low income      1.238760  67.837073
# 3080  ...       29.0  Lower-middle income      1.873885  68.275610
# 3081  ...       28.7  Lower-middle income      3.148128  68.210732
# 3082  ...       28.9  Lower-middle income      3.489478  68.185366
# 3135  ...       36.1           Low income           NaN        NaN
# 3136  ...        NaN           Low income      0.597568  67.374000
# 3137  ...       33.0           Low income      1.081940  67.613000
# 3138  ...       35.3           Low income      1.912595  67.868000
# 3139  ...        NaN           Low income      2.593725  68.135000
# 3140  ...        NaN           Low income      3.343510  68.407000
# 3141  ...        NaN           Low income      6.388322  68.676000
# 3142  ...        NaN           Low income      7.490605  68.939000
# 3143  ...        NaN           Low income      9.080115  69.193000
#
#       population               regime  ruralpopulation     NRrent  \
# 171          NaN  Electoral Autocracy           48.614        NaN
# 172    8111200.0  Electoral Autocracy           48.413  27.426686
# 173    8171950.0  Electoral Autocracy           48.213  25.763396
# 1198    631662.0  Electoral Autocracy           49.168        NaN
# 1199    658388.0  Electoral Autocracy           47.427        NaN
# 1200    686670.0  Electoral Autocracy           45.693        NaN
# 1201    716949.0  Electoral Autocracy           43.967        NaN
# 1577         NaN  Electoral Autocracy           43.902        NaN
# 1578  14858335.0  Electoral Autocracy           43.829  20.120707
# 1579  14858948.0  Electoral Autocracy           43.756  22.395794
# 1580  14909019.0  Electoral Autocracy           43.683  22.346564
# 2071         NaN  Electoral Democracy           42.867        NaN
# 2072   2419594.0  Electoral Democracy           41.778   5.685732
# 2073   2443261.0  Electoral Democracy           40.696   4.433507
# 2074   2468765.0  Electoral Democracy           39.622   4.551278
# 2084   2881783.0  Electoral Democracy           31.903  18.763802
# 2088   3113788.0  Electoral Democracy           31.637  17.337829
# 2089   3170214.0  Electoral Democracy           31.555  20.954655
# 2565         NaN  Electoral Autocracy           26.650        NaN
# 3078         NaN  Electoral Autocracy           32.855        NaN
# 3079  48662400.0  Electoral Autocracy           32.817   4.711853
# 3080  48202470.0  Electoral Autocracy           32.717   3.699726
# 3081  47812949.0  Electoral Autocracy           32.573   3.373148
# 3082  47451626.0  Electoral Autocracy           32.403   3.639399
# 3135         NaN  Electoral Autocracy           53.874        NaN
# 3136  24964450.0  Electoral Autocracy           53.394  28.350164
# 3137  25271850.0  Electoral Autocracy           52.912  26.131211
# 3138  25567650.0  Electoral Autocracy           52.429  27.970681
# 3139  25864350.0  Electoral Autocracy           51.946  24.563249
# 3140  26167000.0  Electoral Autocracy           51.463  22.610015
# 3141  26488250.0  Electoral Autocracy           50.979  33.805859
# 3142  26868000.0  Electoral Autocracy           50.495  29.279700
# 3143  27302800.0  Electoral Autocracy           50.011  34.517225
#
#       urbanpopulation                      worldregions
# 171               NaN  Northern Africa and Western Asia
# 172            51.587  Northern Africa and Western Asia
# 173            51.787  Northern Africa and Western Asia
# 1198           50.832                Sub-Saharan Africa
# 1199           52.573                Sub-Saharan Africa
# 1200           54.307                Sub-Saharan Africa
# 1201           56.033                Sub-Saharan Africa
# 1577              NaN         Central and Southern Asia
# 1578           56.171         Central and Southern Asia
# 1579           56.244         Central and Southern Asia
# 1580           56.317         Central and Southern Asia
# 2071              NaN    Eastern and South-Eastern Asia
# 2072           58.222    Eastern and South-Eastern Asia
# 2073           59.304    Eastern and South-Eastern Asia
# 2074           60.378    Eastern and South-Eastern Asia
# 2084           68.097    Eastern and South-Eastern Asia
# 2088           68.363    Eastern and South-Eastern Asia
# 2089           68.445    Eastern and South-Eastern Asia
# 2565              NaN       Europe and Northern America
# 3078              NaN       Europe and Northern America
# 3079           67.183       Europe and Northern America
# 3080           67.283       Europe and Northern America
# 3081           67.427       Europe and Northern America
# 3082           67.597       Europe and Northern America
# 3135              NaN         Central and Southern Asia
# 3136           46.606         Central and Southern Asia
# 3137           47.088         Central and Southern Asia
# 3138           47.571         Central and Southern Asia
# 3139           48.054         Central and Southern Asia
# 3140           48.537         Central and Southern Asia
# 3141           49.021         Central and Southern Asia
# 3142           49.505         Central and Southern Asia
# 3143           49.989         Central and Southern Asia
#
# [33 rows x 54 columns]

# %%
data[ (data['%CO2savings'] > 10) & (data['Incomeclass'] == 'Low income')  ]
# Out:
#            Country Name Country Code  Year  %population_with_electricity  \
# 171          Azerbaijan          AZE  2000                     98.908222
# 172          Azerbaijan          AZE  2001                     98.623421
# 173          Azerbaijan          AZE  2002                    100.000000
# 1198  Equatorial Guinea          GNQ  2001                           NaN
# 1199  Equatorial Guinea          GNQ  2002                           NaN
# 1200  Equatorial Guinea          GNQ  2003                           NaN
# 2071           Mongolia          MNG  2000                     67.300000
# 2072           Mongolia          MNG  2001                     71.706161
# 2073           Mongolia          MNG  2002                     72.801590
# 2074           Mongolia          MNG  2003                     76.300000
# 3078            Ukraine          UKR  2000                    100.000000
# 3079            Ukraine          UKR  2001                    100.000000
# 3135         Uzbekistan          UZB  2000                     99.572937
# 3136         Uzbekistan          UZB  2001                     99.624657
# 3137         Uzbekistan          UZB  2002                     99.700000
# 3138         Uzbekistan          UZB  2003                     99.702042
# 3139         Uzbekistan          UZB  2004                     99.725365
# 3140         Uzbekistan          UZB  2005                     99.737022
# 3141         Uzbekistan          UZB  2006                     99.490096
# 3142         Uzbekistan          UZB  2007                     99.739029
# 3143         Uzbekistan          UZB  2008                     99.741684
#
#       %GNIgrowth  %netemissionsavings  %CO2savings       %NRD  %FD  %PPdamage  \
# 171     1.137421           -31.614559    11.096608  27.716228  0.0   0.618628
# 172    18.305685           -19.567133    10.451652  20.732720  0.0   0.540368
# 173    32.064224            -9.026698    10.198892   9.562157  0.0   0.487371
# 1198         NaN                  NaN    14.310159        NaN  0.0   3.113382
# 1199         NaN                  NaN    15.590296        NaN  0.0   2.604163
# 1200         NaN                  NaN    17.469984        NaN  0.0   3.108421
# 2071         NaN            -1.393916    12.314631   2.356965  0.0   1.117981
# 2072         NaN            -1.655352    12.081737   1.844769  0.0   1.017996
# 2073         NaN            -1.944064    11.996429   2.438039  0.0   0.948503
# 2074         NaN             8.090429    10.646289   2.020454  0.0   0.837724
# 3078    7.754947            -9.741630    19.650519   1.467658  0.0   0.354199
# 3079   10.449766            -4.328779    16.733725   1.615184  0.0   0.321567
# 3135   -7.046875                  NaN    16.701913  12.793952  0.0   0.978134
# 3136   -5.518212                  NaN    21.389198  19.052519  0.0   0.945026
# 3137    5.071618                  NaN    27.101473  17.428238  0.0   0.901909
# 3138    1.601223                  NaN    26.629226  18.662123  0.0   0.856237
# 3139   11.130161                  NaN    23.188402  16.385330  0.0   0.788450
# 3140    4.894925                  NaN    19.069723  15.025776  0.0   0.764046
# 3141   -2.980788                  NaN    17.075874  21.912502  0.0   0.719646
# 3142   20.186788                  NaN    13.290595  18.116357  0.0   0.648938
# 3143   -1.354388                  NaN    10.613799  21.053846  0.0   0.601444
#
#       ...  GINIindex  Incomeclass  %internetuse        LEB  population  \
# 171   ...        NaN   Low income           NaN        NaN         NaN
# 172   ...       36.5   Low income      0.305565  67.054000   8111200.0
# 173   ...       25.3   Low income      4.999714  67.391000   8171950.0
# 1198  ...        NaN   Low income      0.165260  53.581000    631662.0
# 1199  ...        NaN   Low income      0.321198  53.840000    658388.0
# 1200  ...        NaN   Low income      0.520524  54.064000    686670.0
# 2071  ...        NaN   Low income           NaN        NaN         NaN
# 2072  ...        NaN   Low income      1.653238  63.319000   2419594.0
# 2073  ...       32.9   Low income      2.039573  63.777000   2443261.0
# 2074  ...        NaN   Low income           NaN  64.230000   2468765.0
# 3078  ...        NaN   Low income           NaN        NaN         NaN
# 3079  ...        NaN   Low income      1.238760  67.837073  48662400.0
# 3135  ...       36.1   Low income           NaN        NaN         NaN
# 3136  ...        NaN   Low income      0.597568  67.374000  24964450.0
# 3137  ...       33.0   Low income      1.081940  67.613000  25271850.0
# 3138  ...       35.3   Low income      1.912595  67.868000  25567650.0
# 3139  ...        NaN   Low income      2.593725  68.135000  25864350.0
# 3140  ...        NaN   Low income      3.343510  68.407000  26167000.0
# 3141  ...        NaN   Low income      6.388322  68.676000  26488250.0
# 3142  ...        NaN   Low income      7.490605  68.939000  26868000.0
# 3143  ...        NaN   Low income      9.080115  69.193000  27302800.0
#
#                    regime  ruralpopulation     NRrent  urbanpopulation  \
# 171   Electoral Autocracy           48.614        NaN              NaN
# 172   Electoral Autocracy           48.413  27.426686           51.587
# 173   Electoral Autocracy           48.213  25.763396           51.787
# 1198  Electoral Autocracy           49.168        NaN           50.832
# 1199  Electoral Autocracy           47.427        NaN           52.573
# 1200  Electoral Autocracy           45.693        NaN           54.307
# 2071  Electoral Democracy           42.867        NaN              NaN
# 2072  Electoral Democracy           41.778   5.685732           58.222
# 2073  Electoral Democracy           40.696   4.433507           59.304
# 2074  Electoral Democracy           39.622   4.551278           60.378
# 3078  Electoral Autocracy           32.855        NaN              NaN
# 3079  Electoral Autocracy           32.817   4.711853           67.183
# 3135  Electoral Autocracy           53.874        NaN              NaN
# 3136  Electoral Autocracy           53.394  28.350164           46.606
# 3137  Electoral Autocracy           52.912  26.131211           47.088
# 3138  Electoral Autocracy           52.429  27.970681           47.571
# 3139  Electoral Autocracy           51.946  24.563249           48.054
# 3140  Electoral Autocracy           51.463  22.610015           48.537
# 3141  Electoral Autocracy           50.979  33.805859           49.021
# 3142  Electoral Autocracy           50.495  29.279700           49.505
# 3143  Electoral Autocracy           50.011  34.517225           49.989
#
#                           worldregions
# 171   Northern Africa and Western Asia
# 172   Northern Africa and Western Asia
# 173   Northern Africa and Western Asia
# 1198                Sub-Saharan Africa
# 1199                Sub-Saharan Africa
# 1200                Sub-Saharan Africa
# 2071    Eastern and South-Eastern Asia
# 2072    Eastern and South-Eastern Asia
# 2073    Eastern and South-Eastern Asia
# 2074    Eastern and South-Eastern Asia
# 3078       Europe and Northern America
# 3079       Europe and Northern America
# 3135         Central and Southern Asia
# 3136         Central and Southern Asia
# 3137         Central and Southern Asia
# 3138         Central and Southern Asia
# 3139         Central and Southern Asia
# 3140         Central and Southern Asia
# 3141         Central and Southern Asia
# 3142         Central and Southern Asia
# 3143         Central and Southern Asia
#
# [21 rows x 54 columns]

# %% [markdown]
# ### Select only the categorical columns

# %%
data.select_dtypes(include= ['object'])
# Out:
#      Country Name Country Code      Continent  Incomeclass  \
# 0           Aruba          ABW  North America  High income
# 1           Aruba          ABW  North America  High income
# 2           Aruba          ABW  North America  High income
# 3           Aruba          ABW  North America  High income
# 4           Aruba          ABW  North America  High income
# ...           ...          ...            ...          ...
# 3282     Zimbabwe          ZWE         Africa   Low income
# 3283     Zimbabwe          ZWE         Africa   Low income
# 3284     Zimbabwe          ZWE         Africa   Low income
# 3285     Zimbabwe          ZWE         Africa   Low income
# 3286     Zimbabwe          ZWE         Africa   Low income
#
#                    regime                 worldregions
# 0                     NaN  Latin America and Caribbean
# 1                     NaN  Latin America and Caribbean
# 2                     NaN  Latin America and Caribbean
# 3                     NaN  Latin America and Caribbean
# 4                     NaN  Latin America and Caribbean
# ...                   ...                          ...
# 3282  Electoral Autocracy           Sub-Saharan Africa
# 3283  Electoral Autocracy           Sub-Saharan Africa
# 3284  Electoral Autocracy           Sub-Saharan Africa
# 3285  Electoral Autocracy           Sub-Saharan Africa
# 3286  Electoral Autocracy           Sub-Saharan Africa
#
# [3287 rows x 6 columns]

# %% [markdown]
# ### Select only the numeric columns

# %%
data.select_dtypes(exclude= ['object'])
# Out:
#       Year  %population_with_electricity  %GNIgrowth  %netemissionsavings  \
# 0     2000                     91.660398         NaN            15.392211
# 1     2001                    100.000000         NaN            11.491930
# 2     2002                    100.000000         NaN             3.893620
# 3     2003                    100.000000         NaN             6.713863
# 4     2004                    100.000000         NaN             9.801576
# ...    ...                           ...         ...                  ...
# 3282  2014                     32.300000    0.763955           -14.094023
# 3283  2015                     33.700000   10.749009           -18.882831
# 3284  2016                     39.676228   -0.716048           -11.199213
# 3285  2017                     40.144283   28.172572           -12.700238
# 3286  2018                     40.616360   61.556580                  NaN
#
#       %CO2savings      %NRD       %FD  %PPdamage  \
# 0        2.389134  0.000190  0.000190        NaN
# 1        2.509046  0.000214  0.000214        NaN
# 2        2.721385  0.000223  0.000223        NaN
# 3        2.733676  0.000243  0.000243        NaN
# 4        2.678363  0.000256  0.000256        NaN
# ...           ...       ...       ...        ...
# 3282     2.310859  1.573499  0.000000   1.426705
# 3283     2.381654  0.844003  0.000000   1.492774
# 3284     2.101249  0.823740  0.000000   1.496494
# 3285     2.102515  1.300127  0.000000   1.422511
# 3286     2.003068  2.085152  0.000000   1.422511
#
#       Automated teller machines (ATMs) (per 100,000 adults) - FB.ATM.TOTL.P5  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3282                                           6.034256
# 3283                                           7.157096
# 3284                                           7.073321
# 3285                                           6.889214
# 3286                                           6.625208
#
#       Broad money (% of GDP) - FM.LBL.BMNY.GD.ZS  ...  \
# 0                                      51.834542  ...
# 1                                      53.552517  ...
# 2                                      58.520863  ...
# 3                                      61.196794  ...
# 4                                      57.290048  ...
# ...                                          ...  ...
# 3282                                   22.451986  ...
# 3283                                   23.724442  ...
# 3284                                   27.438656  ...
# 3285                                   32.799112  ...
# 3286                                   25.156144  ...
#
#       Unemployment rate, male (%) - SL_TLF_UEM - 8.5.2  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 3282                                               4.4
# 3283                                               NaN
# 3284                                               NaN
# 3285                                               NaN
# 3286                                               NaN
#
#       Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3282                                                5.2
# 3283                                                NaN
# 3284                                                NaN
# 3285                                                NaN
# 3286                                                NaN
#
#       Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes  \
# 0                                                 2.378
# 1                                                 2.407
# 2                                                 2.437
# 3                                                 2.561
# 4                                                 2.616
# ...                                                 ...
# 3282                                             11.973
# 3283                                             12.170
# 3284                                             10.815
# 3285                                             10.247
# 3286                                             11.341
#
#       GINIindex  %internetuse     LEB  population  ruralpopulation    NRrent  \
# 0           NaN           NaN     NaN         NaN           53.283       NaN
# 1           NaN     17.100000  73.853     92892.0           53.661  0.000712
# 2           NaN     18.800000  73.937     94992.0           54.028  0.000657
# 3           NaN     20.800000  74.038     97016.0           54.394  0.000700
# 4           NaN     23.000000  74.156     98744.0           54.760  0.000685
# ...         ...           ...     ...         ...              ...       ...
# 3282        NaN     16.364740  58.410  13586710.0           67.496  5.531514
# 3283        NaN     22.742818  59.534  13814642.0           67.615  4.561981
# 3284        NaN     23.119989  60.294  14030338.0           67.704  4.473632
# 3285       44.3     24.400000  60.812  14236599.0           67.763  4.844665
# 3286        NaN     25.000000  61.195  14438812.0           67.791  4.363782
#
#       urbanpopulation
# 0                 NaN
# 1              46.339
# 2              45.972
# 3              45.606
# 4              45.240
# ...               ...
# 3282           32.504
# 3283           32.385
# 3284           32.296
# 3285           32.237
# 3286           32.209
#
# [3287 rows x 48 columns]

# %% [markdown]
# ### Groupby on a single column

# %%
data.groupby('Country Name')['%GNIgrowth'].describe()
# Out:
#                      count       mean        std        min       25%  \
# Country Name
# Albania               10.0   2.081124   1.951188  -0.705350  0.656654
# Algeria               19.0   4.111630   5.233191  -4.859333 -0.027337
# Angola                18.0   4.933747  15.030543 -24.254239 -4.263314
# Antigua and Barbuda    0.0        NaN        NaN        NaN       NaN
# Argentina             19.0   1.915892   7.991758 -12.425214 -2.996636
# ...                    ...        ...        ...        ...       ...
# Venezuela, RB         15.0   2.990446  13.231394 -18.791992 -8.707314
# Vietnam               19.0   5.763909   6.415987  -7.985699  4.087641
# West Bank and Gaza     0.0        NaN        NaN        NaN       NaN
# Zambia                 0.0        NaN        NaN        NaN       NaN
# Zimbabwe               9.0  16.243691  19.480589  -0.716048  3.273330
#
#                            50%        75%        max
# Country Name
# Albania               1.842024   3.184916   5.645156
# Algeria               4.781569   7.271400  14.391335
# Angola                6.131289  12.556211  37.239379
# Antigua and Barbuda        NaN        NaN        NaN
# Argentina             0.864590   7.132047  19.991969
# ...                        ...        ...        ...
# Venezuela, RB         2.419874  12.379055  23.167943
# Vietnam               5.145624   7.196193  25.885293
# West Bank and Gaza         NaN        NaN        NaN
# Zambia                     NaN        NaN        NaN
# Zimbabwe             10.749009  21.753105  61.556580
#
# [173 rows x 8 columns]

# %% [markdown]
# ### Find correlation between two numerical columns using corr()

# %%
data['%population_with_electricity'].corr(data['LEB'])
# Out:
# 0.8462018940765006

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## Line Chart

# %% [markdown]
# ### What is the trend of life expeectancy over the years?

# %%
LEB_grouped = data.groupby('Year')['LEB'].mean()
plt.figure(figsize=(10, 6))
sns.lineplot(x=LEB_grouped.index, y=LEB_grouped.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Life Expectancy (years)')
plt.title('Trend of Life Expectancy Over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What is the trend of GDP Per Capita Over Time?

# %%
GDP_grouped = data.groupby('Year')['GDP per capita (current US$) - NY.GDP.PCAP.CD'].mean()
plt.figure(figsize=(10, 6))
sns.lineplot(x=GDP_grouped.index, y=GDP_grouped.values, marker='o')
plt.xlabel('Year')
plt.ylabel('GDP per Capita (current US$)')
plt.title('Trend of GDP per Capita Over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# ### How has the renewable electricity output changed as a percentage of total electricity output over the years?

# %%
grouped_data5 = data.groupby('Year')['Renewable electricity output (% of total electricity output) - EG.ELC.RNEW.ZS'].mean()
plt.figure(figsize=(10, 6))
plt.plot(grouped_data5.index, grouped_data5.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Renewable Electricity Output (% of Total)')
plt.title('Trend of Renewable Electricity Output Over the Years')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What is the annual production of CO2 emissions by Continent over time?

# %%
CO2_grouped = data.groupby(['Year', 'Continent'])['Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes', hue='Continent', data=CO2_grouped)
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (million tonnes)')
plt.title('CO2 Emissions by Continent Over Time')
plt.legend(title='Continent', loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ### How has the Renewable Energy consumption changed over time among different Income Classes?

# %%
RE_grouped = data.groupby(['Year', 'Incomeclass'])['Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS', hue='Incomeclass', data=RE_grouped)
plt.xlabel('Year')
plt.ylabel('Renewable Energy Consumption (%)')
plt.title('Renewable Energy Consumption by Income Classification Over Time')
plt.legend(title='Income Classification', loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What are the gross savings over time by world regions?

# %%
grosssaving_grouped = data.groupby(['Year', 'worldregions'])['Gross savings (% of GDP) - NY.GNS.ICTR.ZS'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Gross savings (% of GDP) - NY.GNS.ICTR.ZS', hue='worldregions', data=grosssaving_grouped)
plt.xlabel('Year')
plt.ylabel('Gross Savings (% of GDP)')
plt.title('Gross Savings Over Time by World Regions')
plt.legend(title='World Regions', loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ###  How has the unemployment rate changed for men and women over time?

# %%
grouped_data2 = data.groupby('Year')['Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2'].mean()
plt.plot(grouped_data2.index, grouped_data2.values, marker='o')
plt.xlabel('Year'); plt.ylabel('Average Unemployment Rate (Female)'); plt.title('Trend of Unemployment Rate (Female)')
plt.show()

# %%
grouped_data3 = data.groupby('Year')['Unemployment rate, male (%) - SL_TLF_UEM - 8.5.2'].mean()
plt.plot(grouped_data3.index, grouped_data3.values, marker='o')
plt.xlabel('Year'); plt.ylabel('Average Unemployment Rate (Male)'); plt.title('Trend of Unemployment Rate (Male)')
plt.show()

# %% [markdown]
# ### What is the trend of internet usage over the years across different continents?

# %%
import seaborn as sns
grouped_data4 = data.groupby(['Year', 'Continent'])['%internetuse'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='%internetuse', hue='Continent', data=grouped_data4)
plt.xlabel('Year')
plt.ylabel('Internet Usage (% of population)')
plt.title('Trend of Internet Usage over Years by Continent')
plt.legend(title='Continent')
plt.show()

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# ### What are the top 5 countries with highest production of CO2 emissions?

# %%
country_emissions = data.groupby('Country Name')['Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes'].sum().reset_index()
top_emitters = country_emissions.sort_values(by='Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes', ascending=False)
top_5_emitters = top_emitters.head(5)
plt.figure(figsize=(12, 6))
sns.barplot(x='Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes', y='Country Name', data=top_5_emitters, palette='Reds_r')
plt.xlabel('CO2 Emissions (million tonnes)')
plt.ylabel('Country')
plt.title('Top 5 Countries with Highest CO2 Emissions')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What are the top 5 countries with lowest production of CO2 emissions?

# %%
country_emissionss = data.groupby('Country Name')['Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes'].sum().reset_index()
lowest_emitters = country_emissionss.sort_values(by='Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes', ascending=True)
top_5_lowest_emitters = lowest_emitters.head(5)
plt.figure(figsize=(12, 6))
sns.barplot(x='Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes', y='Country Name', data=top_5_lowest_emitters, palette='Greens_r')
plt.xlabel('CO2 Emissions (million tonnes)')
plt.ylabel('Country')
plt.title('Top 5 Countries with Lowest CO2 Emissions')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What are the top 10 countries with the highest CO2 emissions in a 2017?

# %%
year_data = data[data['Year'] == 2017]
top_countries =year_data.nlargest(10, 'Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes')
plt.figure(figsize=(12, 6))
sns.barplot(x='Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes', y='Country Name', data=top_countries)
plt.xlabel('CO2 Emissions (million tonnes)')
plt.ylabel('Country')
plt.title('Top Ten Countries with Highest CO2 Emissions in 2017')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What are the top 10 countries with the highest GDP in 2014?

# %%
year_data2 = data[data['Year'] == 2014]
top_countries2 = year_data2.nlargest(10, 'GDP (current US$) - NY.GDP.MKTP.CD')
plt.figure(figsize=(12, 6))
sns.barplot(x='GDP (current US$) - NY.GDP.MKTP.CD', y='Country Name', data=top_countries2)
plt.xlabel('GDP (current US$)')
plt.ylabel('Country')
plt.title('Top Ten Countries with Highest GDP (current US$) in 2014')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What are the top 5 income classifications with the highest proportion of seats held by women in national parliaments in 2015?

# %%
year_data4 = data[data['Year'] == 2015]
top_income_classifications = year_data4.nlargest(5, 'Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS')
plt.figure(figsize=(10, 6))
sns.barplot(x='Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS', y='Incomeclass', data=top_income_classifications)
plt.xlabel('Proportion of Seats Held by Women (%)')
plt.ylabel('Income Classification')
plt.title('Top Five Income Classifications with Highest Proportion of Seats Held by Women in 2015')
plt.grid(True)
plt.show()

# %% [markdown]
# ### What is the GDP distribution among different income classifications over the years?

# %%
grouped_dataa = data.groupby('Incomeclass')['GDP (current US$) - NY.GDP.MKTP.CD'].mean()
plt.figure(figsize=(10, 6))
sns.barplot(x=grouped_dataa.index, y=grouped_dataa.values)
plt.xlabel('Income Classification')
plt.ylabel('Mean GDP (current US$)')
plt.title('Distribution of GDP among Income Classifications')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### How does the life expectancy vary among different continents over the years?

# %%
grouped_dataaa = data.groupby('Continent')['LEB'].mean()
plt.figure(figsize=(10, 6))
sns.barplot(x=grouped_dataaa.index, y=grouped_dataaa.values)
plt.xlabel('Continent')
plt.ylabel('Mean Life Expectancy (years)')
plt.title('Comparison of Life Expectancy among Continents')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# ### How does internet usage correlate with GDP per capita?

# %%
# Create a scatterplot
plt.figure(figsize=(10, 6))  

# Customize the plot 
plt.title('Correlation between Internet Usage and GDP per Capita')
plt.xlabel('Internet Usage (% of Population)')
plt.ylabel('GDP per Capita (current US$)')

# Plot the data points
plt.scatter(data['%internetuse'], data['GDP per capita (current US$) - NY.GDP.PCAP.CD'], alpha=0.6, c='blue', edgecolors='k')

# Add gridlines (optional)
plt.grid(True, linestyle='--', alpha=0.5)

# Show the plot
plt.show()

# %% [markdown]
# ### How does internet usage correlate with GDP per capita in different income classes?

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))  
plt.title('Correlation between Internet Usage and GDP per Capita by Income Class')
plt.xlabel('Internet Usage (% of Population)')
plt.ylabel('GDP per Capita (current US$)')
sns.scatterplot(x="%internetuse", y="GDP per capita (current US$) - NY.GDP.PCAP.CD", hue="Incomeclass", data=data, palette='Set1')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### How does Life Expectancy at Birth correlate with GDP per capita in different world regions?

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))  
plt.title('Correlation between Life Expectancy and GDP per Capita by World Region')
plt.xlabel('Life Expectancy at Birth (years)')
plt.ylabel('GDP per Capita (current US$)')
sns.scatterplot(x="LEB", y="GDP per capita (current US$) - NY.GDP.PCAP.CD", hue="worldregions", data=data, palette='Set1')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title='World Region')
plt.show()

# %% [markdown]
# ### How does GDP per capita correlate with CO2 emissions in different regions?

# %%
grouped_data6 = data.groupby('worldregions')[['GDP per capita (current US$) - NY.GDP.PCAP.CD', 'Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes']].mean()
plt.figure(figsize=(10, 6))
sns.scatterplot(x='GDP per capita (current US$) - NY.GDP.PCAP.CD', y='Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes', hue=grouped_data6.index, data=grouped_data6, s=120)
plt.xlabel('GDP per capita')
plt.ylabel('CO2 Emissions')
plt.title('Correlation between GDP per Capita and CO2 Emissions by Region')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### What is the distribution of Life Expectancy at Birth?

# %%
plt.hist(data['LEB'], bins=20)
plt.xlabel('Life Expectancy at Birth'); plt.ylabel('Frequency'); plt.title('Distribution of Life Expectancy')
plt.show()

# %% [markdown]
# ## Box Plot

# %% [markdown]
# ### How does the distribution of GINI Index vary among World Regions?

# %%
import seaborn as sns
sns.boxplot(x= 'GINIindex', y='worldregions', data=data)
plt.gca().set_facecolor('#FFFF00')
plt.xlabel('GINI Index')
plt.ylabel('World Regions')
plt.title('Distribution of Gini Index by World Regions')
# Out:
# Text(0.5, 1.0, 'Distribution of Gini Index by World Regions')

# %% [markdown]
# ### Are there significant differences in the proportion of seats held by women in national parliaments among different world regions?

# %%
sns.boxplot(x= 'worldregions', y='Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS', data=data)
plt.gca().set_facecolor('#FFFF00')
plt.xlabel('World Regions')
plt.ylabel('Proportion of Seats Held by Women (%)')
plt.title('Distribution of Women\'s Representation in Parliaments by World Regions')
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# ## Heatmap

# %%
dff = data[data['Country Name'] == 'Pakistan']
correlation_matrix = dff.corr()
plt.figure(figsize=(18, 12))  
sns.heatmap(correlation_matrix, cmap='coolwarm')
plt.title('Correlation Heatmap of Pakistan')
plt.show()
# Out:
# /var/folders/gq/g2c67fl53q1cybg7x2g_vc5h0000gn/T/ipykernel_12929/715122044.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = dff.corr()
